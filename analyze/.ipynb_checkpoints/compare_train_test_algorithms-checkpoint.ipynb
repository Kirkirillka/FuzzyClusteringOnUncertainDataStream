# %%
from sqlalchemy import create_engine

ADDR="10.114.22.20"
PORT=55432
USERNAME="postgres"
PASSWORD="postgres"
DBNAME="postgres"

ALGO_NAMES = [
    "dfuzzystream",
    "sfcm",
    "fcm",
    "umicro"
]

ALGO_TRAIN_PREFIX="train_without_history_270620_"
ALGO_TEST_PREFIX="test_without_history_270620_"

ALGORITHM = ALGO_NAMES[0]



TRAIN_ALGORITHM_PREFIX_NAME=f"{ALGO_TRAIN_PREFIX}{ALGORITHM}"
TRAIN_POINT_TABLE=f"{TRAIN_ALGORITHM_PREFIX_NAME}_points"
TRAIN_CLUSTER_TABLE=f"{TRAIN_ALGORITHM_PREFIX_NAME}_clusters"
TRAIN_PREDICTION_TABLE=f"{TRAIN_ALGORITHM_PREFIX_NAME}_predict"


TEST_ALGORITHM_PREFIX_NAME=f"{ALGO_TEST_PREFIX}{ALGORITHM}"
TEST_POINT_TABLE=f"{TEST_ALGORITHM_PREFIX_NAME}_points"
TEST_CLUSTER_TABLE=f"{TEST_ALGORITHM_PREFIX_NAME}_clusters"
TEST_PREDICTION_TABLE=f"{TEST_ALGORITHM_PREFIX_NAME}_predict"

engine = create_engine(f"postgresql://{USERNAME}:{PASSWORD}@{ADDR}:{PORT}/{DBNAME}")

# %%
#Use timestampts to save results
import datetime
current_time = datetime.date.today()

# %%
## Read data

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation


df_train_origin = pd.read_sql_query(f"""
SELECT {TRAIN_PREDICTION_TABLE}.timestamp, data_point, {TRAIN_PREDICTION_TABLE}.cluster_label, data_point_membership, centroid FROM
              {TRAIN_PREDICTION_TABLE} join {TRAIN_CLUSTER_TABLE}
                  on {TRAIN_PREDICTION_TABLE}.timestamp = {TRAIN_CLUSTER_TABLE}.timestamp and
                     {TRAIN_PREDICTION_TABLE}.cluster_label = {TRAIN_CLUSTER_TABLE}.unique_label""", engine)



df_test_origin = pd.read_sql_query(f"""
SELECT {TEST_PREDICTION_TABLE}.timestamp, data_point, {TEST_PREDICTION_TABLE}.cluster_label, data_point_membership, centroid FROM
              {TEST_PREDICTION_TABLE} join {TEST_CLUSTER_TABLE}
                  on {TEST_PREDICTION_TABLE}.timestamp = {TEST_CLUSTER_TABLE}.timestamp and
                     {TEST_PREDICTION_TABLE}.cluster_label = {TEST_CLUSTER_TABLE}.unique_label""", engine)

# %%
df_train = df_train_origin.copy()
df_test = df_test_origin.copy()

# %%
# FOR TRAIN DATA
#transform timestamp from string into correct format
df_train["timestamp"] = df_train["timestamp"].apply(lambda x: pd.Timestamp(x))
 
# transform data_point and centroid into numpy arrays
casted_data_points = df_train["data_point"].apply(lambda x: np.array(x))
df_train["data_point"] = casted_data_points

# add has for data points
df_train["data_point_unique_id"] = df_train["data_point"].apply(str)

casted_centroids = df_train["centroid"].apply(lambda x: np.array(x))
df_train["centroid"] = casted_centroids



# FOR TEST DATA
#transform timestamp from string into correct format
df_test["timestamp"] = df_test["timestamp"].apply(lambda x: pd.Timestamp(x))
 
# transform data_point and centroid into numpy arrays
casted_data_points = df_test["data_point"].apply(lambda x: np.array(x))
df_test["data_point"] = casted_data_points

# add has for data points
df_test["data_point_unique_id"] = df_test["data_point"].apply(str)

casted_centroids = df_test["centroid"].apply(lambda x: np.array(x))
df_test["centroid"] = casted_centroids

# %%
# set timestamp as index by default

df_train = df_train.set_index("timestamp")
df_test = df_test.set_index("timestamp")

# %%
# Changes in number of cluster across time range

fig,ax = plt.subplots(nrows=2,ncols=1,figsize=(20,20))

df_train[["cluster_label"]].plot(y="cluster_label", ax=ax[0], title=f"Cluster number changes in data stream by {TRAIN_ALGORITHM_PREFIX_NAME.upper()}");
df_test[["cluster_label"]].plot(y="cluster_label", ax=ax[1], title=f"Cluster number changes in data stream by {TEST_ALGORITHM_PREFIX_NAME.upper()}");

# %%
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_cluster_number_changes_{current_time}.pdf")
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_cluster_number_changesa_{current_time}.png")

# %% [markdown]
# ## Draw Data Stream

# %%
# The following code is required in case
# If you want to bind the color of points with its timestamp
train_cmap = mpl.cm.get_cmap('YlGn_r')
test_cmap = mpl.cm.get_cmap('YlOrRd_r')

train_timestamp_enum = dict(map(lambda x: (x[1], x[0]),enumerate(set(df_train.reset_index()["timestamp"]))))
train_time_normalizer = mpl.colors.Normalize(vmin=min(train_timestamp_enum.values()), vmax=max(train_timestamp_enum.values()))


test_timestamp_enum = dict(map(lambda x: (x[1], x[0]),enumerate(set(df_test.reset_index()["timestamp"]))))
test_time_normalizer = mpl.colors.Normalize(vmin=min(test_timestamp_enum.values()), vmax=max(test_timestamp_enum.values()))

# %%
# Prepare layout

fig, ax = plt.subplots(figsize=(20,20))

## Draw data points
x_train = np.stack(df_train["data_point"].values)[:,0]
y_train = np.stack(df_train["data_point"].values)[:,1]
#train_membership=df_train["data_point_membership"].fillna(0).astype(np.float)
#train_color = df_train.reset_index()["timestamp"].map(lambda x: train_cmap(train_time_normalizer(train_timestamp_enum[x])))

x_test = np.stack(df_test["data_point"].values)[:,0]
y_test = np.stack(df_test["data_point"].values)[:,1]
#test_membership=df_train["data_point_membership"].fillna(0).astype(np.float)
#test_color = df_test.reset_index()["timestamp"].map(lambda x: test_cmap(test_time_normalizer(test_timestamp_enum[x])))

ax.scatter(x_train,y_train, alpha=0.5, c="blue",label=f"{TRAIN_ALGORITHM_PREFIX_NAME.upper()}");
ax.scatter(x_test, y_test, alpha=0.5, c="green", label=f"{TEST_ALGORITHM_PREFIX_NAME.upper()}");
plt.title(f"Ground Truth and Uncertain Data Streams source processed by {ALGORITHM.upper()}. Mode: {ALGO_TRAIN_PREFIX}")
plt.legend();

# %%
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_data_stream_{current_time}.pdf")
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_data_stream_{current_time}.png")

# %%
pd.pivot_table(df_train, index=["timestamp","data_point_unique_id","cluster_label"],values="data_point_membership" )
# Out:
#                                                                  data_point_membership
# timestamp               data_point_unique_id      cluster_label
# 2020-07-08 00:48:10.293 [ 1.02087622 -1.84281187] 1                           0.004893
#                                                   3                           0.985374
#                                                   4                           0.000002
#                         [ 2.06693335 14.65375375] 1                           0.105941
#                                                   3                           0.067817
# ...                                                                                ...
# 2020-07-08 00:49:12.162 [65.43055766 -1.63974672] 3                           0.034176
#                                                   4                           0.012191
#                         [67.22493227 -4.46119909] 1                           0.033790
#                                                   3                           0.075521
#                                                   4                           0.022993
#
# [15030 rows x 1 columns]

# %%
# Calculate summarized weights for clusters over time range
def calculate_cluster_weights(df):
    
    cluster_weights = df.groupby(["cluster_label"]).apply(lambda x: x["data_point_membership"].sum() / len(x))

    return np.stack(list(enumerate(cluster_weights)))

calculate_cluster_weights(df_train)
# Out:
# array([[0.        , 0.19623955],
#        [1.        , 0.47558282],
#        [2.        , 0.24204373],
#        [3.        , 0.29208286]])

# %%
calculate_cluster_weights(df_test)
# Out:
# array([[0.        , 0.17044816],
#        [1.        , 0.5586122 ],
#        [2.        , 0.25556135],
#        [3.        , 0.35498404]])

# %% [markdown]
# ## Modified F1-Score

# %%
# Modified F1-Score for Fuzzy Clusters
# Let's we have a predicted result for a timestamp T
# We expect here is N data points with C clusters
# Therefore, the input structure will be: (N,C)
#
# If we have 50 data points with 3 clusters, then
# - Sum of weights for a fuzzy cluster j: \sum_{i=1}^{|N|} w_{ij} -> (C,)


def f1_fuzzy(left_df, right_df):
    
    _l = pd.pivot_table(left_df, index=["data_point_unique_id"], columns="cluster_label", values="data_point_membership" ).fillna(0)
    _r = pd.pivot_table(right_df, index=["data_point_unique_id"], columns="cluster_label", values="data_point_membership" ).fillna(0)
    
    _l_fuzzy_clusters_weights = calculate_cluster_weights(left_df)
    _r_fuzzy_clusters_weights = calculate_cluster_weights(right_df)
    
    # Trunkate _l and _r to the minimum size
    min_length = min(len(_l),len(_r))
    
    
    diff = 1 - np.sqrt(np.power((np.array(_l[:min_length]) - np.array(_r[:min_length])),2))
    
    # calculate clusters precision
    precision_by_clusters = (diff / _l_fuzzy_clusters_weights[:,1])
    # calculate clusters recall
    recall_by_clusters = (diff / _r_fuzzy_clusters_weights[:,1])
    
    # calculate f1 score for each point
    f1_score = np.nan_to_num( 2 * (precision_by_clusters * recall_by_clusters) / (precision_by_clusters + recall_by_clusters))
    
    # calculate overall f1 score
    f1_score_overall = np.sum(_r_fuzzy_clusters_weights[:,1]/len(_r_fuzzy_clusters_weights) * np.max(f1_score,0) / np.sum(_r_fuzzy_clusters_weights[:,1]) )
    
    return diff, precision_by_clusters, recall_by_clusters, f1_score, f1_score_overall


_,_,_,_,f1 = f1_fuzzy(df_train, df_test)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide

# %%
print("Overall F1 score:", f1)
# Out:
# Overall F1 score: 0.7715550814232266

# %%
min_length = min(len(df_train), len(df_test)) 


window = 10

f1_dynamic = []

for i in range(0,min_length, window):
    r = i + window
    
    train = df_train.iloc[i:r]
    test = df_test.iloc[i:r]
    
    if len(train) != len(test):
        continue
    
    try:
        _,_,_,f1_components,f1 = f1_fuzzy(train, test)
    except ValueError as e:
        print(f"Different number of clusters,slices: {i}:{r}! Set current f1_score to -1")
        f1_dynamic.append(-1)
    else:    
        f1_dynamic.append(f1)
# Out:
# Different number of clusters,slices: 0:10! Set current f1_score to -1
# Different number of clusters,slices: 10:20! Set current f1_score to -1
# Different number of clusters,slices: 20:30! Set current f1_score to -1
# Different number of clusters,slices: 30:40! Set current f1_score to -1
# Different number of clusters,slices: 80:90! Set current f1_score to -1
# Different number of clusters,slices: 90:100! Set current f1_score to -1
# Different number of clusters,slices: 100:110! Set current f1_score to -1
# Different number of clusters,slices: 110:120! Set current f1_score to -1
# Different number of clusters,slices: 120:130! Set current f1_score to -1
# Different number of clusters,slices: 130:140! Set current f1_score to -1
# Different number of clusters,slices: 140:150! Set current f1_score to -1
# Different number of clusters,slices: 150:160! Set current f1_score to -1
# Different number of clusters,slices: 160:170! Set current f1_score to -1
# Different number of clusters,slices: 170:180! Set current f1_score to -1
# Different number of clusters,slices: 210:220! Set current f1_score to -1
# Different number of clusters,slices: 220:230! Set current f1_score to -1
# Different number of clusters,slices: 240:250! Set current f1_score to -1
# Different number of clusters,slices: 250:260! Set current f1_score to -1
# Different number of clusters,slices: 280:290! Set current f1_score to -1
# Different number of clusters,slices: 290:300! Set current f1_score to -1
# Different number of clusters,slices: 320:330! Set current f1_score to -1
# Different number of clusters,slices: 330:340! Set current f1_score to -1
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in true_divide
# Different number of clusters,slices: 400:410! Set current f1_score to -1
# Different number of clusters,slices: 420:430! Set current f1_score to -1
# Different number of clusters,slices: 440:450! Set current f1_score to -1
# Different number of clusters,slices: 460:470! Set current f1_score to -1
# Different number of clusters,slices: 480:490! Set current f1_score to -1
# Different number of clusters,slices: 750:760! Set current f1_score to -1
# Different number of clusters,slices: 800:810! Set current f1_score to -1
# Different number of clusters,slices: 900:910! Set current f1_score to -1
# Different number of clusters,slices: 910:920! Set current f1_score to -1
# Different number of clusters,slices: 930:940! Set current f1_score to -1
# Different number of clusters,slices: 950:960! Set current f1_score to -1
# Different number of clusters,slices: 960:970! Set current f1_score to -1
# Different number of clusters,slices: 970:980! Set current f1_score to -1
# Different number of clusters,slices: 980:990! Set current f1_score to -1
# Different number of clusters,slices: 1000:1010! Set current f1_score to -1
# Different number of clusters,slices: 1040:1050! Set current f1_score to -1
# Different number of clusters,slices: 1060:1070! Set current f1_score to -1
# Different number of clusters,slices: 1140:1150! Set current f1_score to -1
# Different number of clusters,slices: 1180:1190! Set current f1_score to -1
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in true_divide
# Different number of clusters,slices: 1210:1220! Set current f1_score to -1
# Different number of clusters,slices: 1220:1230! Set current f1_score to -1
# Different number of clusters,slices: 1240:1250! Set current f1_score to -1
# Different number of clusters,slices: 1250:1260! Set current f1_score to -1
# Different number of clusters,slices: 1280:1290! Set current f1_score to -1
# Different number of clusters,slices: 1290:1300! Set current f1_score to -1
# Different number of clusters,slices: 1310:1320! Set current f1_score to -1
# Different number of clusters,slices: 1320:1330! Set current f1_score to -1
# Different number of clusters,slices: 1350:1360! Set current f1_score to -1
# Different number of clusters,slices: 1360:1370! Set current f1_score to -1
# Different number of clusters,slices: 1390:1400! Set current f1_score to -1
# Different number of clusters,slices: 1400:1410! Set current f1_score to -1
# Different number of clusters,slices: 1420:1430! Set current f1_score to -1
# Different number of clusters,slices: 1430:1440! Set current f1_score to -1
# Different number of clusters,slices: 1680:1690! Set current f1_score to -1
# Different number of clusters,slices: 1740:1750! Set current f1_score to -1
# Different number of clusters,slices: 1760:1770! Set current f1_score to -1
# Different number of clusters,slices: 1780:1790! Set current f1_score to -1
# Different number of clusters,slices: 1800:1810! Set current f1_score to -1
# Different number of clusters,slices: 1820:1830! Set current f1_score to -1
# Different number of clusters,slices: 1840:1850! Set current f1_score to -1
# Different number of clusters,slices: 1850:1860! Set current f1_score to -1
# Different number of clusters,slices: 1860:1870! Set current f1_score to -1
# Different number of clusters,slices: 1880:1890! Set current f1_score to -1
# Different number of clusters,slices: 1890:1900! Set current f1_score to -1
# Different number of clusters,slices: 1900:1910! Set current f1_score to -1
# Different number of clusters,slices: 1920:1930! Set current f1_score to -1
# Different number of clusters,slices: 1940:1950! Set current f1_score to -1
# Different number of clusters,slices: 1970:1980! Set current f1_score to -1
# Different number of clusters,slices: 2000:2010! Set current f1_score to -1
# Different number of clusters,slices: 2010:2020! Set current f1_score to -1
# Different number of clusters,slices: 2020:2030! Set current f1_score to -1
# Different number of clusters,slices: 2060:2070! Set current f1_score to -1
# Different number of clusters,slices: 2110:2120! Set current f1_score to -1
# Different number of clusters,slices: 2140:2150! Set current f1_score to -1
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in true_divide
# Different number of clusters,slices: 2280:2290! Set current f1_score to -1
# Different number of clusters,slices: 2330:2340! Set current f1_score to -1
# Different number of clusters,slices: 2410:2420! Set current f1_score to -1
# Different number of clusters,slices: 2480:2490! Set current f1_score to -1
# Different number of clusters,slices: 2530:2540! Set current f1_score to -1
# Different number of clusters,slices: 2540:2550! Set current f1_score to -1
# Different number of clusters,slices: 2550:2560! Set current f1_score to -1
# Different number of clusters,slices: 2560:2570! Set current f1_score to -1
# Different number of clusters,slices: 2580:2590! Set current f1_score to -1
# Different number of clusters,slices: 2670:2680! Set current f1_score to -1
# Different number of clusters,slices: 2680:2690! Set current f1_score to -1
# Different number of clusters,slices: 2710:2720! Set current f1_score to -1
# Different number of clusters,slices: 2720:2730! Set current f1_score to -1
# Different number of clusters,slices: 2730:2740! Set current f1_score to -1
# Different number of clusters,slices: 2770:2780! Set current f1_score to -1
# Different number of clusters,slices: 2820:2830! Set current f1_score to -1
# Different number of clusters,slices: 2860:2870! Set current f1_score to -1
# Different number of clusters,slices: 2880:2890! Set current f1_score to -1
# Different number of clusters,slices: 2920:2930! Set current f1_score to -1
# Different number of clusters,slices: 2940:2950! Set current f1_score to -1
# Different number of clusters,slices: 2980:2990! Set current f1_score to -1
# Different number of clusters,slices: 3020:3030! Set current f1_score to -1
# Different number of clusters,slices: 3140:3150! Set current f1_score to -1
# Different number of clusters,slices: 3150:3160! Set current f1_score to -1
# Different number of clusters,slices: 3260:3270! Set current f1_score to -1
# Different number of clusters,slices: 3300:3310! Set current f1_score to -1
# Different number of clusters,slices: 3340:3350! Set current f1_score to -1
# Different number of clusters,slices: 3380:3390! Set current f1_score to -1
# Different number of clusters,slices: 3420:3430! Set current f1_score to -1
# Different number of clusters,slices: 3430:3440! Set current f1_score to -1
# Different number of clusters,slices: 3460:3470! Set current f1_score to -1
# Different number of clusters,slices: 3470:3480! Set current f1_score to -1
# Different number of clusters,slices: 3510:3520! Set current f1_score to -1
# Different number of clusters,slices: 3530:3540! Set current f1_score to -1
# Different number of clusters,slices: 3590:3600! Set current f1_score to -1
# Different number of clusters,slices: 3610:3620! Set current f1_score to -1
# Different number of clusters,slices: 3630:3640! Set current f1_score to -1
# Different number of clusters,slices: 3640:3650! Set current f1_score to -1
# Different number of clusters,slices: 3660:3670! Set current f1_score to -1
# Different number of clusters,slices: 3670:3680! Set current f1_score to -1
# Different number of clusters,slices: 3680:3690! Set current f1_score to -1
# Different number of clusters,slices: 3700:3710! Set current f1_score to -1
# Different number of clusters,slices: 3710:3720! Set current f1_score to -1
# Different number of clusters,slices: 3720:3730! Set current f1_score to -1
# Different number of clusters,slices: 3740:3750! Set current f1_score to -1
# Different number of clusters,slices: 3750:3760! Set current f1_score to -1
# Different number of clusters,slices: 3760:3770! Set current f1_score to -1
# Different number of clusters,slices: 3790:3800! Set current f1_score to -1
# Different number of clusters,slices: 3810:3820! Set current f1_score to -1
# Different number of clusters,slices: 3830:3840! Set current f1_score to -1
# Different number of clusters,slices: 3860:3870! Set current f1_score to -1
# Different number of clusters,slices: 3870:3880! Set current f1_score to -1
# Different number of clusters,slices: 3890:3900! Set current f1_score to -1
# Different number of clusters,slices: 3910:3920! Set current f1_score to -1
# Different number of clusters,slices: 3920:3930! Set current f1_score to -1
# Different number of clusters,slices: 3930:3940! Set current f1_score to -1
# Different number of clusters,slices: 3950:3960! Set current f1_score to -1
# Different number of clusters,slices: 3970:3980! Set current f1_score to -1
# Different number of clusters,slices: 3990:4000! Set current f1_score to -1
# Different number of clusters,slices: 4000:4010! Set current f1_score to -1
# Different number of clusters,slices: 4010:4020! Set current f1_score to -1
# Different number of clusters,slices: 4030:4040! Set current f1_score to -1
# Different number of clusters,slices: 4040:4050! Set current f1_score to -1
# Different number of clusters,slices: 4070:4080! Set current f1_score to -1
# Different number of clusters,slices: 4080:4090! Set current f1_score to -1
# Different number of clusters,slices: 4100:4110! Set current f1_score to -1
# Different number of clusters,slices: 4110:4120! Set current f1_score to -1
# Different number of clusters,slices: 4120:4130! Set current f1_score to -1
# Different number of clusters,slices: 4130:4140! Set current f1_score to -1
# Different number of clusters,slices: 4140:4150! Set current f1_score to -1
# Different number of clusters,slices: 4150:4160! Set current f1_score to -1
# Different number of clusters,slices: 4170:4180! Set current f1_score to -1
# Different number of clusters,slices: 4180:4190! Set current f1_score to -1
# Different number of clusters,slices: 4190:4200! Set current f1_score to -1
# Different number of clusters,slices: 4200:4210! Set current f1_score to -1
# Different number of clusters,slices: 4240:4250! Set current f1_score to -1
# Different number of clusters,slices: 4250:4260! Set current f1_score to -1
# Different number of clusters,slices: 4270:4280! Set current f1_score to -1
# Different number of clusters,slices: 4280:4290! Set current f1_score to -1
# Different number of clusters,slices: 4290:4300! Set current f1_score to -1
# Different number of clusters,slices: 4340:4350! Set current f1_score to -1
# Different number of clusters,slices: 4350:4360! Set current f1_score to -1
# Different number of clusters,slices: 4370:4380! Set current f1_score to -1
# Different number of clusters,slices: 4380:4390! Set current f1_score to -1
# Different number of clusters,slices: 4400:4410! Set current f1_score to -1
# Different number of clusters,slices: 4420:4430! Set current f1_score to -1
# Different number of clusters,slices: 4440:4450! Set current f1_score to -1
# Different number of clusters,slices: 4450:4460! Set current f1_score to -1
# Different number of clusters,slices: 4480:4490! Set current f1_score to -1
# Different number of clusters,slices: 4490:4500! Set current f1_score to -1
# Different number of clusters,slices: 4510:4520! Set current f1_score to -1
# Different number of clusters,slices: 4520:4530! Set current f1_score to -1
# Different number of clusters,slices: 4550:4560! Set current f1_score to -1
# Different number of clusters,slices: 4570:4580! Set current f1_score to -1
# Different number of clusters,slices: 4580:4590! Set current f1_score to -1
# Different number of clusters,slices: 4620:4630! Set current f1_score to -1
# Different number of clusters,slices: 4640:4650! Set current f1_score to -1
# Different number of clusters,slices: 4660:4670! Set current f1_score to -1
# Different number of clusters,slices: 4680:4690! Set current f1_score to -1
# Different number of clusters,slices: 4700:4710! Set current f1_score to -1
# Different number of clusters,slices: 4720:4730! Set current f1_score to -1
# Different number of clusters,slices: 4740:4750! Set current f1_score to -1
# Different number of clusters,slices: 4780:4790! Set current f1_score to -1
# Different number of clusters,slices: 4790:4800! Set current f1_score to -1
# Different number of clusters,slices: 4820:4830! Set current f1_score to -1
# Different number of clusters,slices: 4830:4840! Set current f1_score to -1
# Different number of clusters,slices: 4850:4860! Set current f1_score to -1
# Different number of clusters,slices: 4870:4880! Set current f1_score to -1
# Different number of clusters,slices: 4910:4920! Set current f1_score to -1
# Different number of clusters,slices: 4950:4960! Set current f1_score to -1
# Different number of clusters,slices: 4990:5000! Set current f1_score to -1
# Different number of clusters,slices: 5050:5060! Set current f1_score to -1
# Different number of clusters,slices: 5080:5090! Set current f1_score to -1
# Different number of clusters,slices: 5120:5130! Set current f1_score to -1
# Different number of clusters,slices: 5440:5450! Set current f1_score to -1
# Different number of clusters,slices: 5450:5460! Set current f1_score to -1
# Different number of clusters,slices: 5490:5500! Set current f1_score to -1
# Different number of clusters,slices: 5530:5540! Set current f1_score to -1
# Different number of clusters,slices: 5560:5570! Set current f1_score to -1
# Different number of clusters,slices: 5570:5580! Set current f1_score to -1
# Different number of clusters,slices: 5600:5610! Set current f1_score to -1
# Different number of clusters,slices: 5630:5640! Set current f1_score to -1
# Different number of clusters,slices: 5640:5650! Set current f1_score to -1
# Different number of clusters,slices: 5670:5680! Set current f1_score to -1
# Different number of clusters,slices: 5680:5690! Set current f1_score to -1
# Different number of clusters,slices: 5690:5700! Set current f1_score to -1
# Different number of clusters,slices: 5700:5710! Set current f1_score to -1
# Different number of clusters,slices: 5710:5720! Set current f1_score to -1
# Different number of clusters,slices: 5720:5730! Set current f1_score to -1
# Different number of clusters,slices: 5730:5740! Set current f1_score to -1
# Different number of clusters,slices: 5740:5750! Set current f1_score to -1
# Different number of clusters,slices: 5760:5770! Set current f1_score to -1
# Different number of clusters,slices: 5790:5800! Set current f1_score to -1
# Different number of clusters,slices: 5800:5810! Set current f1_score to -1
# Different number of clusters,slices: 5830:5840! Set current f1_score to -1
# Different number of clusters,slices: 5880:5890! Set current f1_score to -1
# Different number of clusters,slices: 5890:5900! Set current f1_score to -1
# Different number of clusters,slices: 5900:5910! Set current f1_score to -1
# Different number of clusters,slices: 5910:5920! Set current f1_score to -1
# Different number of clusters,slices: 5920:5930! Set current f1_score to -1
# Different number of clusters,slices: 5960:5970! Set current f1_score to -1
# Different number of clusters,slices: 6000:6010! Set current f1_score to -1
# Different number of clusters,slices: 6040:6050! Set current f1_score to -1
# Different number of clusters,slices: 6050:6060! Set current f1_score to -1
# Different number of clusters,slices: 6260:6270! Set current f1_score to -1
# Different number of clusters,slices: 6270:6280! Set current f1_score to -1
# Different number of clusters,slices: 6300:6310! Set current f1_score to -1
# Different number of clusters,slices: 6310:6320! Set current f1_score to -1
# Different number of clusters,slices: 6340:6350! Set current f1_score to -1
# Different number of clusters,slices: 6350:6360! Set current f1_score to -1
# Different number of clusters,slices: 6370:6380! Set current f1_score to -1
# Different number of clusters,slices: 6380:6390! Set current f1_score to -1
# Different number of clusters,slices: 6400:6410! Set current f1_score to -1
# Different number of clusters,slices: 6420:6430! Set current f1_score to -1
# Different number of clusters,slices: 6430:6440! Set current f1_score to -1
# Different number of clusters,slices: 6460:6470! Set current f1_score to -1
# Different number of clusters,slices: 6470:6480! Set current f1_score to -1
# Different number of clusters,slices: 6480:6490! Set current f1_score to -1
# Different number of clusters,slices: 6520:6530! Set current f1_score to -1
# Different number of clusters,slices: 6530:6540! Set current f1_score to -1
# Different number of clusters,slices: 6540:6550! Set current f1_score to -1
# Different number of clusters,slices: 6600:6610! Set current f1_score to -1
# Different number of clusters,slices: 6610:6620! Set current f1_score to -1
# Different number of clusters,slices: 6630:6640! Set current f1_score to -1
# Different number of clusters,slices: 6640:6650! Set current f1_score to -1
# Different number of clusters,slices: 6650:6660! Set current f1_score to -1
# Different number of clusters,slices: 6670:6680! Set current f1_score to -1
# Different number of clusters,slices: 6700:6710! Set current f1_score to -1
# Different number of clusters,slices: 6710:6720! Set current f1_score to -1
# Different number of clusters,slices: 6730:6740! Set current f1_score to -1
# Different number of clusters,slices: 6740:6750! Set current f1_score to -1
# Different number of clusters,slices: 6750:6760! Set current f1_score to -1
# Different number of clusters,slices: 6770:6780! Set current f1_score to -1
# Different number of clusters,slices: 6780:6790! Set current f1_score to -1
# Different number of clusters,slices: 6800:6810! Set current f1_score to -1
# Different number of clusters,slices: 6810:6820! Set current f1_score to -1
# Different number of clusters,slices: 6870:6880! Set current f1_score to -1
# Different number of clusters,slices: 6900:6910! Set current f1_score to -1
# Different number of clusters,slices: 6920:6930! Set current f1_score to -1
# Different number of clusters,slices: 6930:6940! Set current f1_score to -1
# Different number of clusters,slices: 6950:6960! Set current f1_score to -1
# Different number of clusters,slices: 6990:7000! Set current f1_score to -1
# Different number of clusters,slices: 7030:7040! Set current f1_score to -1
# Different number of clusters,slices: 7070:7080! Set current f1_score to -1
# Different number of clusters,slices: 7110:7120! Set current f1_score to -1
# Different number of clusters,slices: 7120:7130! Set current f1_score to -1
# Different number of clusters,slices: 7140:7150! Set current f1_score to -1
# Different number of clusters,slices: 7160:7170! Set current f1_score to -1
# Different number of clusters,slices: 7170:7180! Set current f1_score to -1
# Different number of clusters,slices: 7180:7190! Set current f1_score to -1
# Different number of clusters,slices: 7200:7210! Set current f1_score to -1
# Different number of clusters,slices: 7210:7220! Set current f1_score to -1
# Different number of clusters,slices: 7230:7240! Set current f1_score to -1
# Different number of clusters,slices: 7240:7250! Set current f1_score to -1
# Different number of clusters,slices: 7260:7270! Set current f1_score to -1
# Different number of clusters,slices: 7270:7280! Set current f1_score to -1
# Different number of clusters,slices: 7310:7320! Set current f1_score to -1
# Different number of clusters,slices: 7330:7340! Set current f1_score to -1
# Different number of clusters,slices: 7360:7370! Set current f1_score to -1
# Different number of clusters,slices: 7370:7380! Set current f1_score to -1
# Different number of clusters,slices: 7390:7400! Set current f1_score to -1
# Different number of clusters,slices: 7400:7410! Set current f1_score to -1
# Different number of clusters,slices: 7410:7420! Set current f1_score to -1
# Different number of clusters,slices: 7440:7450! Set current f1_score to -1
# Different number of clusters,slices: 7450:7460! Set current f1_score to -1
# Different number of clusters,slices: 7480:7490! Set current f1_score to -1
# Different number of clusters,slices: 7490:7500! Set current f1_score to -1
# Different number of clusters,slices: 7570:7580! Set current f1_score to -1
# Different number of clusters,slices: 7590:7600! Set current f1_score to -1
# Different number of clusters,slices: 7610:7620! Set current f1_score to -1
# Different number of clusters,slices: 7630:7640! Set current f1_score to -1
# Different number of clusters,slices: 7650:7660! Set current f1_score to -1
# Different number of clusters,slices: 7690:7700! Set current f1_score to -1
# Different number of clusters,slices: 7700:7710! Set current f1_score to -1
# Different number of clusters,slices: 7870:7880! Set current f1_score to -1
# Different number of clusters,slices: 8130:8140! Set current f1_score to -1
# Different number of clusters,slices: 8150:8160! Set current f1_score to -1
# Different number of clusters,slices: 8220:8230! Set current f1_score to -1
# Different number of clusters,slices: 8250:8260! Set current f1_score to -1
# Different number of clusters,slices: 8280:8290! Set current f1_score to -1
# Different number of clusters,slices: 8320:8330! Set current f1_score to -1
# Different number of clusters,slices: 8340:8350! Set current f1_score to -1
# Different number of clusters,slices: 8350:8360! Set current f1_score to -1
# Different number of clusters,slices: 8380:8390! Set current f1_score to -1
# Different number of clusters,slices: 8400:8410! Set current f1_score to -1
# Different number of clusters,slices: 8410:8420! Set current f1_score to -1
# Different number of clusters,slices: 8450:8460! Set current f1_score to -1
# Different number of clusters,slices: 8470:8480! Set current f1_score to -1
# Different number of clusters,slices: 8510:8520! Set current f1_score to -1
# Different number of clusters,slices: 8520:8530! Set current f1_score to -1
# Different number of clusters,slices: 8550:8560! Set current f1_score to -1
# Different number of clusters,slices: 8560:8570! Set current f1_score to -1
# Different number of clusters,slices: 8580:8590! Set current f1_score to -1
# Different number of clusters,slices: 8600:8610! Set current f1_score to -1
# Different number of clusters,slices: 8620:8630! Set current f1_score to -1
# Different number of clusters,slices: 8630:8640! Set current f1_score to -1
# Different number of clusters,slices: 8650:8660! Set current f1_score to -1
# Different number of clusters,slices: 8660:8670! Set current f1_score to -1
# Different number of clusters,slices: 8680:8690! Set current f1_score to -1
# Different number of clusters,slices: 8750:8760! Set current f1_score to -1
# Different number of clusters,slices: 8770:8780! Set current f1_score to -1
# Different number of clusters,slices: 8780:8790! Set current f1_score to -1
# Different number of clusters,slices: 8800:8810! Set current f1_score to -1
# Different number of clusters,slices: 8820:8830! Set current f1_score to -1
# Different number of clusters,slices: 8850:8860! Set current f1_score to -1
# Different number of clusters,slices: 8890:8900! Set current f1_score to -1
# Different number of clusters,slices: 8900:8910! Set current f1_score to -1
# Different number of clusters,slices: 8920:8930! Set current f1_score to -1
# Different number of clusters,slices: 8930:8940! Set current f1_score to -1
# Different number of clusters,slices: 8960:8970! Set current f1_score to -1
# Different number of clusters,slices: 9010:9020! Set current f1_score to -1
# Different number of clusters,slices: 9050:9060! Set current f1_score to -1
# Different number of clusters,slices: 9090:9100! Set current f1_score to -1
# Different number of clusters,slices: 9110:9120! Set current f1_score to -1
# Different number of clusters,slices: 9130:9140! Set current f1_score to -1
# Different number of clusters,slices: 9140:9150! Set current f1_score to -1
# Different number of clusters,slices: 9150:9160! Set current f1_score to -1
# Different number of clusters,slices: 9180:9190! Set current f1_score to -1
# Different number of clusters,slices: 9220:9230! Set current f1_score to -1
# Different number of clusters,slices: 9330:9340! Set current f1_score to -1
# Different number of clusters,slices: 9340:9350! Set current f1_score to -1
# Different number of clusters,slices: 9380:9390! Set current f1_score to -1
# Different number of clusters,slices: 9420:9430! Set current f1_score to -1
# Different number of clusters,slices: 9450:9460! Set current f1_score to -1
# Different number of clusters,slices: 9490:9500! Set current f1_score to -1
# Different number of clusters,slices: 9530:9540! Set current f1_score to -1
# Different number of clusters,slices: 9570:9580! Set current f1_score to -1
# Different number of clusters,slices: 9580:9590! Set current f1_score to -1
# Different number of clusters,slices: 9610:9620! Set current f1_score to -1
# Different number of clusters,slices: 9630:9640! Set current f1_score to -1
# Different number of clusters,slices: 9640:9650! Set current f1_score to -1
# Different number of clusters,slices: 9650:9660! Set current f1_score to -1
# Different number of clusters,slices: 9680:9690! Set current f1_score to -1
# Different number of clusters,slices: 9740:9750! Set current f1_score to -1
# Different number of clusters,slices: 9760:9770! Set current f1_score to -1
# Different number of clusters,slices: 9770:9780! Set current f1_score to -1
# Different number of clusters,slices: 9780:9790! Set current f1_score to -1
# Different number of clusters,slices: 9790:9800! Set current f1_score to -1
# Different number of clusters,slices: 9800:9810! Set current f1_score to -1
# Different number of clusters,slices: 9810:9820! Set current f1_score to -1
# Different number of clusters,slices: 9820:9830! Set current f1_score to -1
# Different number of clusters,slices: 9850:9860! Set current f1_score to -1
# Different number of clusters,slices: 9860:9870! Set current f1_score to -1
# Different number of clusters,slices: 9870:9880! Set current f1_score to -1
# Different number of clusters,slices: 9890:9900! Set current f1_score to -1
# Different number of clusters,slices: 9900:9910! Set current f1_score to -1
# Different number of clusters,slices: 9910:9920! Set current f1_score to -1
# Different number of clusters,slices: 9940:9950! Set current f1_score to -1
# Different number of clusters,slices: 9980:9990! Set current f1_score to -1
# Different number of clusters,slices: 9990:10000! Set current f1_score to -1
# Different number of clusters,slices: 10000:10010! Set current f1_score to -1
# Different number of clusters,slices: 10010:10020! Set current f1_score to -1
# Different number of clusters,slices: 10030:10040! Set current f1_score to -1
# Different number of clusters,slices: 10110:10120! Set current f1_score to -1
# Different number of clusters,slices: 10120:10130! Set current f1_score to -1
# Different number of clusters,slices: 10130:10140! Set current f1_score to -1
# Different number of clusters,slices: 10190:10200! Set current f1_score to -1
# Different number of clusters,slices: 10220:10230! Set current f1_score to -1
# Different number of clusters,slices: 10230:10240! Set current f1_score to -1
# Different number of clusters,slices: 10250:10260! Set current f1_score to -1
# Different number of clusters,slices: 10260:10270! Set current f1_score to -1
# Different number of clusters,slices: 10300:10310! Set current f1_score to -1
# Different number of clusters,slices: 10320:10330! Set current f1_score to -1
# Different number of clusters,slices: 10330:10340! Set current f1_score to -1
# Different number of clusters,slices: 10350:10360! Set current f1_score to -1
# Different number of clusters,slices: 10360:10370! Set current f1_score to -1
# Different number of clusters,slices: 10380:10390! Set current f1_score to -1
# Different number of clusters,slices: 10420:10430! Set current f1_score to -1
# Different number of clusters,slices: 10430:10440! Set current f1_score to -1
# Different number of clusters,slices: 10460:10470! Set current f1_score to -1
# Different number of clusters,slices: 10500:10510! Set current f1_score to -1
# Different number of clusters,slices: 10540:10550! Set current f1_score to -1
# Different number of clusters,slices: 10590:10600! Set current f1_score to -1
# Different number of clusters,slices: 10630:10640! Set current f1_score to -1
# Different number of clusters,slices: 10700:10710! Set current f1_score to -1
# Different number of clusters,slices: 10740:10750! Set current f1_score to -1
# Different number of clusters,slices: 10790:10800! Set current f1_score to -1
# Different number of clusters,slices: 10810:10820! Set current f1_score to -1
# Different number of clusters,slices: 10820:10830! Set current f1_score to -1
# Different number of clusters,slices: 10930:10940! Set current f1_score to -1
# Different number of clusters,slices: 10950:10960! Set current f1_score to -1
# Different number of clusters,slices: 10960:10970! Set current f1_score to -1
# Different number of clusters,slices: 10970:10980! Set current f1_score to -1
# Different number of clusters,slices: 11000:11010! Set current f1_score to -1
# Different number of clusters,slices: 11010:11020! Set current f1_score to -1
# Different number of clusters,slices: 11070:11080! Set current f1_score to -1
# Different number of clusters,slices: 11080:11090! Set current f1_score to -1
# Different number of clusters,slices: 11160:11170! Set current f1_score to -1
# Different number of clusters,slices: 11200:11210! Set current f1_score to -1
# Different number of clusters,slices: 11260:11270! Set current f1_score to -1
# Different number of clusters,slices: 11290:11300! Set current f1_score to -1
# Different number of clusters,slices: 11300:11310! Set current f1_score to -1
# Different number of clusters,slices: 11310:11320! Set current f1_score to -1
# Different number of clusters,slices: 11360:11370! Set current f1_score to -1
# Different number of clusters,slices: 11380:11390! Set current f1_score to -1
# Different number of clusters,slices: 11400:11410! Set current f1_score to -1
# Different number of clusters,slices: 11410:11420! Set current f1_score to -1
# Different number of clusters,slices: 11420:11430! Set current f1_score to -1
# Different number of clusters,slices: 11460:11470! Set current f1_score to -1
# Different number of clusters,slices: 11470:11480! Set current f1_score to -1
# Different number of clusters,slices: 11480:11490! Set current f1_score to -1
# Different number of clusters,slices: 11490:11500! Set current f1_score to -1
# Different number of clusters,slices: 11510:11520! Set current f1_score to -1
# Different number of clusters,slices: 11580:11590! Set current f1_score to -1
# Different number of clusters,slices: 11590:11600! Set current f1_score to -1
# Different number of clusters,slices: 11600:11610! Set current f1_score to -1
# Different number of clusters,slices: 11640:11650! Set current f1_score to -1
# Different number of clusters,slices: 11650:11660! Set current f1_score to -1
# Different number of clusters,slices: 11660:11670! Set current f1_score to -1
# Different number of clusters,slices: 11670:11680! Set current f1_score to -1
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in true_divide
# Different number of clusters,slices: 11710:11720! Set current f1_score to -1
# Different number of clusters,slices: 11740:11750! Set current f1_score to -1
# Different number of clusters,slices: 11750:11760! Set current f1_score to -1
# Different number of clusters,slices: 11800:11810! Set current f1_score to -1
# Different number of clusters,slices: 11850:11860! Set current f1_score to -1
# Different number of clusters,slices: 11990:12000! Set current f1_score to -1
# Different number of clusters,slices: 12030:12040! Set current f1_score to -1
# Different number of clusters,slices: 12070:12080! Set current f1_score to -1
# Different number of clusters,slices: 12110:12120! Set current f1_score to -1
# Different number of clusters,slices: 12160:12170! Set current f1_score to -1
# Different number of clusters,slices: 12180:12190! Set current f1_score to -1
# Different number of clusters,slices: 12210:12220! Set current f1_score to -1
# Different number of clusters,slices: 12230:12240! Set current f1_score to -1
# Different number of clusters,slices: 12240:12250! Set current f1_score to -1
# Different number of clusters,slices: 12260:12270! Set current f1_score to -1
# Different number of clusters,slices: 12280:12290! Set current f1_score to -1
# Different number of clusters,slices: 12300:12310! Set current f1_score to -1
# Different number of clusters,slices: 12320:12330! Set current f1_score to -1
# Different number of clusters,slices: 12340:12350! Set current f1_score to -1
# Different number of clusters,slices: 12350:12360! Set current f1_score to -1
# Different number of clusters,slices: 12390:12400! Set current f1_score to -1
# Different number of clusters,slices: 12410:12420! Set current f1_score to -1
# Different number of clusters,slices: 12420:12430! Set current f1_score to -1
# Different number of clusters,slices: 12430:12440! Set current f1_score to -1
# Different number of clusters,slices: 12450:12460! Set current f1_score to -1
# Different number of clusters,slices: 12460:12470! Set current f1_score to -1
# Different number of clusters,slices: 12490:12500! Set current f1_score to -1
# Different number of clusters,slices: 12520:12530! Set current f1_score to -1
# Different number of clusters,slices: 12530:12540! Set current f1_score to -1
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide
# Different number of clusters,slices: 12620:12630! Set current f1_score to -1
# Different number of clusters,slices: 12660:12670! Set current f1_score to -1
# Different number of clusters,slices: 12680:12690! Set current f1_score to -1
# Different number of clusters,slices: 12690:12700! Set current f1_score to -1
# Different number of clusters,slices: 12700:12710! Set current f1_score to -1
# Different number of clusters,slices: 12730:12740! Set current f1_score to -1
# Different number of clusters,slices: 12760:12770! Set current f1_score to -1
# Different number of clusters,slices: 12800:12810! Set current f1_score to -1
# Different number of clusters,slices: 12810:12820! Set current f1_score to -1
# Different number of clusters,slices: 12840:12850! Set current f1_score to -1
# Different number of clusters,slices: 12850:12860! Set current f1_score to -1
# Different number of clusters,slices: 12880:12890! Set current f1_score to -1
# Different number of clusters,slices: 12900:12910! Set current f1_score to -1
# Different number of clusters,slices: 12970:12980! Set current f1_score to -1
# Different number of clusters,slices: 12990:13000! Set current f1_score to -1
# Different number of clusters,slices: 13000:13010! Set current f1_score to -1
# Different number of clusters,slices: 13030:13040! Set current f1_score to -1
# Different number of clusters,slices: 13040:13050! Set current f1_score to -1
# Different number of clusters,slices: 13050:13060! Set current f1_score to -1
# Different number of clusters,slices: 13180:13190! Set current f1_score to -1
# Different number of clusters,slices: 13230:13240! Set current f1_score to -1
# Different number of clusters,slices: 13250:13260! Set current f1_score to -1
# Different number of clusters,slices: 13270:13280! Set current f1_score to -1
# Different number of clusters,slices: 13310:13320! Set current f1_score to -1
# Different number of clusters,slices: 13380:13390! Set current f1_score to -1
# Different number of clusters,slices: 13400:13410! Set current f1_score to -1
# Different number of clusters,slices: 13410:13420! Set current f1_score to -1
# Different number of clusters,slices: 13750:13760! Set current f1_score to -1
# Different number of clusters,slices: 13780:13790! Set current f1_score to -1
# Different number of clusters,slices: 13960:13970! Set current f1_score to -1
# Different number of clusters,slices: 13990:14000! Set current f1_score to -1
# Different number of clusters,slices: 14030:14040! Set current f1_score to -1
# Different number of clusters,slices: 14060:14070! Set current f1_score to -1
# Different number of clusters,slices: 14070:14080! Set current f1_score to -1
# Different number of clusters,slices: 14100:14110! Set current f1_score to -1
# Different number of clusters,slices: 14110:14120! Set current f1_score to -1
# Different number of clusters,slices: 14140:14150! Set current f1_score to -1
# Different number of clusters,slices: 14150:14160! Set current f1_score to -1
# Different number of clusters,slices: 14180:14190! Set current f1_score to -1
# Different number of clusters,slices: 14220:14230! Set current f1_score to -1
# Different number of clusters,slices: 14260:14270! Set current f1_score to -1
# Different number of clusters,slices: 14270:14280! Set current f1_score to -1
# Different number of clusters,slices: 14300:14310! Set current f1_score to -1
# Different number of clusters,slices: 14310:14320! Set current f1_score to -1
# Different number of clusters,slices: 14320:14330! Set current f1_score to -1
# Different number of clusters,slices: 14330:14340! Set current f1_score to -1
# Different number of clusters,slices: 14350:14360! Set current f1_score to -1
# Different number of clusters,slices: 14360:14370! Set current f1_score to -1
# Different number of clusters,slices: 14380:14390! Set current f1_score to -1
# Different number of clusters,slices: 14390:14400! Set current f1_score to -1
# Different number of clusters,slices: 14410:14420! Set current f1_score to -1
# Different number of clusters,slices: 14420:14430! Set current f1_score to -1
# Different number of clusters,slices: 14430:14440! Set current f1_score to -1
# Different number of clusters,slices: 14440:14450! Set current f1_score to -1
# Different number of clusters,slices: 14450:14460! Set current f1_score to -1
# Different number of clusters,slices: 14460:14470! Set current f1_score to -1
# Different number of clusters,slices: 14470:14480! Set current f1_score to -1
# Different number of clusters,slices: 14480:14490! Set current f1_score to -1
# Different number of clusters,slices: 14490:14500! Set current f1_score to -1
# Different number of clusters,slices: 14500:14510! Set current f1_score to -1
# Different number of clusters,slices: 14510:14520! Set current f1_score to -1
# Different number of clusters,slices: 14560:14570! Set current f1_score to -1
# Different number of clusters,slices: 14570:14580! Set current f1_score to -1
# Different number of clusters,slices: 14600:14610! Set current f1_score to -1
# Different number of clusters,slices: 14620:14630! Set current f1_score to -1
# Different number of clusters,slices: 14640:14650! Set current f1_score to -1
# Different number of clusters,slices: 14670:14680! Set current f1_score to -1
# Different number of clusters,slices: 14700:14710! Set current f1_score to -1
# Different number of clusters,slices: 14710:14720! Set current f1_score to -1
# Different number of clusters,slices: 14730:14740! Set current f1_score to -1
# Different number of clusters,slices: 14740:14750! Set current f1_score to -1
# Different number of clusters,slices: 14800:14810! Set current f1_score to -1
# Different number of clusters,slices: 14810:14820! Set current f1_score to -1
# Different number of clusters,slices: 14820:14830! Set current f1_score to -1
# Different number of clusters,slices: 14830:14840! Set current f1_score to -1
# Different number of clusters,slices: 14860:14870! Set current f1_score to -1
# Different number of clusters,slices: 14880:14890! Set current f1_score to -1
# Different number of clusters,slices: 14890:14900! Set current f1_score to -1
# Different number of clusters,slices: 14910:14920! Set current f1_score to -1
# Different number of clusters,slices: 14920:14930! Set current f1_score to -1
# Different number of clusters,slices: 14930:14940! Set current f1_score to -1
# Different number of clusters,slices: 14940:14950! Set current f1_score to -1
# Different number of clusters,slices: 14950:14960! Set current f1_score to -1
# Different number of clusters,slices: 14970:14980! Set current f1_score to -1
# Different number of clusters,slices: 14980:14990! Set current f1_score to -1

# %%
#Calculate over timestamps

fig, ax = plt.subplots(figsize=(20,20))

ax.plot(f1_dynamic, label="F1 score")
plt.legend()
plt.grid()
plt.title(f"F1 Score changes Over Data Batches processed by {ALGORITHM.upper()}. Mode: {ALGO_TRAIN_PREFIX}");

# %%
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_f1_score_changes_{current_time}.pdf")
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_f1_score_changes_{current_time}.png")

# %% [markdown]
# ## Fuzzy Silhouette

# %%
# Silhouette

df = df_train[["data_point","cluster_label","data_point_membership"]]

cluster_weights = calculate_cluster_weights(df)

# %%
from sklearn.metrics import silhouette_score,silhouette_samples
from sklearn.metrics import pairwise_distances

# %%
def get_unique_data_points(local_df):
        
    unique_data_points = local_df[["data_point_unique_id","data_point"]].groupby("data_point_unique_id").apply(lambda x: x.iloc[-1])
    
    cluster_label_with_highest_membership = local_df[["data_point_unique_id","cluster_label","data_point_membership"]]
    
    def get_index_of_max_membership_cluster(piece):
        
        memberships = np.array(piece["data_point_membership"])
        
        max_index = np.argmax(memberships)
        
        max_cluster_label = np.array(df["cluster_label"])[max_index]
        
        return max_cluster_label
        
    unique_data_points_labels = cluster_label_with_highest_membership.groupby("data_point_unique_id").apply(get_index_of_max_membership_cluster)
    
    unique_data_points["cluster_label"] = unique_data_points_labels
    
    return unique_data_points



def first_second_membership_diff(local_df):
    
    data_points = local_df[["data_point_unique_id","cluster_label","data_point_membership"]]
     
    def get_difference_func(piece):
        
        memberships = np.sort(np.unique(np.array(piece["data_point_membership"])))
        
        difference = 0
        
        if len(memberships)>=2:
            difference= memberships[-1] - memberships[-2] 
        elif len(memberships) == 1:
            difference= memberships[0]
        else:
            difference=0
            
        return pd.Series(difference, name="difference")
        
    membership_difference = local_df.groupby(["data_point_unique_id","cluster_label"])\
        .apply(get_difference_func)
    
    foo = pd.DataFrame(membership_difference)
    
    final = pd.pivot(foo.reset_index(), index="data_point_unique_id", columns="cluster_label",values=0).fillna(0)
    
    return  final




def calculate_fuzzy_silhouette_score(local_df, a=1):
    
    unique_points_from_fuzzy_set = get_unique_data_points(local_df)
    membership_difference = first_second_membership_diff(local_df)
    points = np.stack(unique_points_from_fuzzy_set["data_point"])
    
    unique_cluster_labels = local_df["cluster_label"].unique()
    
    # Then iterate over each fuzzy_cluster:
    silhouette_components = []
    
    for expected_cluster_label in unique_cluster_labels:
        
        labels = unique_points_from_fuzzy_set["cluster_label"] == expected_cluster_label
        
        if len(np.unique(labels))>1:
            
            diff_powered = membership_difference[expected_cluster_label].pow(a)
        
            s = silhouette_samples(points, labels)
        
            silhouette_components.append((diff_powered * s).sum() / diff_powered.sum())
            
        else:
            # Cluster contains only singleton values
            silhouette_components.append(0)
        
    foo = np.array(silhouette_components)
    
    return foo, np.sum(foo)


silh_train = calculate_fuzzy_silhouette_score(df_train)
silh_test = calculate_fuzzy_silhouette_score(df_test)

# %%
print("Fuzzy Silhouette for Train:", silh_train[-1])
print("Fuzzy Silhouette for Test:", silh_test[-1])
# Out:
# Fuzzy Silhouette for Train: 0.006989341942145703
# Fuzzy Silhouette for Test: 0.010956437139499687

# %%
# Let's try to calculate for several timestamps

silhouette_train_dynamic = df_train.groupby("timestamp").apply(lambda x: calculate_fuzzy_silhouette_score(x)[-1])
silhouette_test_dynamic = df_test.groupby("timestamp").apply(lambda x: calculate_fuzzy_silhouette_score(x)[-1])

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax.plot(silhouette_train_dynamic.values,label="Train Fuzzy Silh")
ax.plot(silhouette_test_dynamic.values, label="Test Fuzzy Silh")
plt.grid()
plt.title(f"Fuzzy Silhouette Changes Over Data Batches processed by {ALGORITHM.upper()}. Mode: {ALGO_TRAIN_PREFIX}")
plt.legend();

# %%
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_Fuzzy_Silh_score_changes_{current_time}.pdf")
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_Fuzzy_Silh_score_changes_{current_time}.png")

# %% [markdown]
# ## Fuzzy hypervolume

# %% [markdown]
# The less the value the better

# %%
def calculate_fuzzy_covariance_matrix(df):
    diff = np.stack(df["data_point"]) - np.stack(df["centroid"])
    total_cluster_membership = df["data_point_membership"].sum()
    memberships=df["data_point_membership"]
    
    foo = np.stack([(m * v) for m, v in zip(memberships, np.dot(diff.T,diff)) ])

    
    return foo / total_cluster_membership


def calculate_fuzzy_hypervolume(df):
    
    fuzzy_covariance_matrix_elements = df.groupby("cluster_label").apply(calculate_fuzzy_covariance_matrix)
    
    return fuzzy_covariance_matrix_elements.map(lambda x: np.sqrt(np.linalg.det(x)) ).sum()

# %%
# First, calculate for overall datasets
fhv_train_overall = calculate_fuzzy_hypervolume(df_train)
fhv_test_overall = calculate_fuzzy_hypervolume(df_test)

# %%
print(f"Overall Fuzzy Hypervolume for Train: {fhv_train_overall}")
print(f"Overall Fuzzy Hypervolume for Test: {fhv_test_overall}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-5ee7e82b0b98> in <module>
# ----> 1 print(f"Overall Fuzzy Hypervolume for Train: {fhv_train}")
#       2 print(f"Overall Fuzzy Hypervolume for Test: {fhv_test}")
#
# NameError: name 'fhv_train' is not defined

# %%
# Calculate over data stream timestamps

fvh_train_dynamic = df_train.groupby("timestamp").apply(calculate_fuzzy_hypervolume)
fvh_test_dynamic = df_test.groupby("timestamp").apply(calculate_fuzzy_hypervolume)

# %%
fig, ax = plt.subplots(figsize=(20,20))

train_fsilh_plt = ax.plot(fvh_train_dynamic.values,label="Train FHV")
test_fsilh_plt = ax.plot(fvh_test_dynamic.values, label="Test FHV")
plt.legend()
plt.grid()
plt.title(f"Fuzzy Hyper Volume Cluster CVI changes over batches processed by {ALGORITHM.upper()}. Mode: {ALGO_TRAIN_PREFIX}");

# %%
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_FHV_score_changes_{current_time}.pdf")
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_FHV_score_changes_{current_time}.png")

# %% [markdown]
# ## Average Partition Density

# %% [markdown]
# The larger value the better

# %%
def calculate_sum_of_central_members(df):
    
    diff = np.stack(df["data_point"]) - np.stack(df["centroid"])
    total_cluster_membership = df["data_point_membership"].sum()
    memberships=df["data_point_membership"]
    
    fuzzy_covariance_matrix = np.stack([(m * v) for m, v in zip(memberships, np.dot(diff.T,diff)) ]) / total_cluster_membership
    
    
    def check_condition(x):
        is_added = False
        try:
            is_added = np.dot(np.dot(np.linalg.inv(fuzzy_covariance_matrix),x.T),x) <1
        except numpy.linalg.LinAlgError as e:
            # Singular matrix appear in Inverse matrix
            # Cannot find inverse
            pass
        finally:
            return is_added
            
            
        
    
    count_bool = np.apply_along_axis(check_condition,axis=1, arr=diff)
    
    memberships[count_bool]
    
    
    return memberships[count_bool].sum()

# %%
def calculate_average_partition_density(df):
    
    R = df.groupby("cluster_label").apply(calculate_sum_of_central_members)
    
    fuzzy_covariance_matrix_elements = df.groupby("cluster_label").apply(calculate_fuzzy_covariance_matrix)
    
    number_of_clusters = len(df["cluster_label"].unique())
    
    
    return np.sum(list(map(lambda x:x[1]/ np.sqrt(np.linalg.det(x[0]) ), zip(fuzzy_covariance_matrix_elements,R)))) / number_of_clusters

# %%
# Calculate overall APD

APD_train_overall = calculate_average_partition_density(df_train)
APD_test_overall = calculate_average_partition_density(df_test)

# %%
print(f"Overall Average Partition Density for Train: {APD_train_overall}")
print(f"Overall Average Partition Density for Test: {APD_test_overall}")

# %%
# Calculate over data stream timestamps

APD_train_dynamic = df_train.groupby("timestamp").apply(calculate_average_partition_density)
APD_test_dynamic = df_test.groupby("timestamp").apply(calculate_average_partition_density)

# %%
fig, ax = plt.subplots(figsize=(20,20))
train_fsilh_plt = ax.plot(APD_train_dynamic.values,label="Train APD")
test_fsilh_plt = ax.plot(APD_test_dynamic.values, label="Test APD")
plt.legend()
plt.grid()
plt.title("Average Partition Density CVI changes over batches. processed by {ALGORITHM.upper()}. Mode: {ALGO_TRAIN_PREFIX}");

# %%
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_APD_score_changes_{current_time}.pdf")
fig.savefig(f"images/analysis_{ALGORITHM}-{ALGO_TRAIN_PREFIX}_APD_score_changes_{current_time}.png")
